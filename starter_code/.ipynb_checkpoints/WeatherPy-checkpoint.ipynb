# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # Observable Trends
#
# 1. Collecting weather data from 559 random and diverse cities around the world using the OpenWeatherMap API,the data illustrated maximum temperature(in Fahrenheit),humidity(%),cloudiness(%)and wind speed(in mph)with the corresponding city,and with respect to the geo-coordinate,Latitude.
# 2. There seems to be little to no correlation between humidity and Latitude as well as with cloudiness and Latitude. The scatter plot visualizations display a considerable amount of heterogeneity even at similar Latitudes.
# 3. Finally, wind speeds increase in the upper and lower halves on the hemisphere.
# 4. The correlation coeffient and linear regression model shows a strong negative correlation between latitude and  northern hemisphere and in southern hemisphere, the correlation coefficient and linear regression model shows a positive correlation between latitude and maximum temperature.
# 5. The correlation coefficent and linear regression model for humidity vs latitude shows a weak positive correlation for both hemispheres.
# 6. The correlation coefficient and linear regression model show a weak positive correlation between cloudiness and latitude in the northern hemisphere and weak positive correlation in the southern hemisphere.
# 7. The correlation coefficient and linear regression model show a weak positive correlation between wind speed(mph) and latitude in the northern hemisphere and shows an almost moderate negative correlation between wind speed(mph) and latitude in the southern hemisphere.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# !pip install citipy

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create url
# Get Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -37.64,
#         "lat": 65.61
#     },
#     "weather": [
#         {
#             "id": 500,
#             "main": "Rain",
#             "description": "light rain",
#             "icon": "10n"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 30.2,
#         "feels_like": 23.4,
#         "temp_min": 30.2,
#         "temp_max": 30.2,
#         "pressure": 1005,
#         "humidity": 68
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 3.36,
#         "deg": 200
#     },
#     "clouds": {
#         "all": 93
#     },
#     "dt": 1604801028,
#     "sys": {
#         "type": 1,
#         "id": 81,
#         "country": "GL",
#         "sunrise": 1604745952,
#         "sunset": 1604770963
#     },
#     "timezone": -10800,
#     "id": 3424607,
#     "name": "Tasiilaq",
#     "cod": 200
# }

# %%
print(requests.get(query_url + city))
# Out:
# <Response [200]>

# %%
# Set Up Lists to Hold Reponse Info
city_name = []
country = []
date = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []

# Processing Record Counter Starting a 1
processing_record = 1

# Print Starting Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop Through List of Cities & Perform a Request for Data on Each
for city in cities:

# Exception Handling
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # Increase Processing Record Counter by 1 For Each Loop
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    continue

# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Barrow
# City not found. Skipping...
# Processing Record 2 | Guérande
# Processing Record 3 | Ushuaia
# Processing Record 4 | George Town
# Processing Record 5 | Prince Rupert
# Processing Record 6 | Punta Arenas
# Processing Record 7 | Lompoc
# Processing Record 8 | Illapel
# Processing Record 9 | Mar del Plata
# Processing Record 10 | Faanui
# Processing Record 11 | Saint-François
# Processing Record 12 | Pittsburg
# Processing Record 13 | Cape Town
# Processing Record 14 | Jamestown
# Processing Record 15 | Naze
# Processing Record 16 | Bluff
# Processing Record 17 | Vaini
# Processing Record 18 | Necochea
# Processing Record 19 | Busselton
# City not found. Skipping...
# Processing Record 20 | Arraial do Cabo
# Processing Record 21 | Albany
# Processing Record 22 | Avarua
# Processing Record 23 | Hamilton
# Processing Record 24 | Sainte-Thècle
# Processing Record 25 | Port Alfred
# Processing Record 26 | Itaituba
# Processing Record 27 | Azuaga
# Processing Record 28 | Kapaa
# Processing Record 29 | Porgera
# Processing Record 30 | Sorong
# Processing Record 31 | Hithadhoo
# Processing Record 32 | Dikson
# Processing Record 33 | Muros
# Processing Record 34 | Sarata
# Processing Record 35 | Mataura
# Processing Record 36 | Hermanus
# Processing Record 37 | Isla Vista
# Processing Record 38 | Hilo
# Processing Record 39 | Chokurdakh
# Processing Record 40 | Meulaboh
# Processing Record 41 | Fort Nelson
# Processing Record 42 | Atuona
# Processing Record 43 | Iqaluit
# City not found. Skipping...
# Processing Record 44 | Safonovo
# Processing Record 45 | Ejigbo
# Processing Record 46 | Cidreira
# Processing Record 47 | Călmăţuiu
# Processing Record 48 | Berlevåg
# Processing Record 49 | Marsh Harbour
# Processing Record 50 | Bereda
# Processing Record 51 | Bethel
# Processing Record 52 | Eminabad
# Processing Record 53 | São Domingos
# Processing Record 54 | Ahipara
# Processing Record 55 | Kasempa
# Processing Record 56 | Buala
# Processing Record 57 | Rikitea
# Processing Record 58 | Hobart
# Processing Record 59 | Rantepao
# Processing Record 60 | Iquitos
# Processing Record 61 | Codrington
# Processing Record 62 | East London
# Processing Record 63 | Bambous Virieux
# Processing Record 64 | Dordrecht
# Processing Record 65 | Aksu
# Processing Record 66 | Progreso
# Processing Record 67 | Tasiilaq
# Processing Record 68 | Ankazobe
# Processing Record 69 | Ondjiva
# Processing Record 70 | Calgary
# Processing Record 71 | Khatanga
# Processing Record 72 | Chebarkul'
# Processing Record 73 | Aklavik
# Processing Record 74 | Mthatha
# City not found. Skipping...
# Processing Record 75 | Villa Carlos Paz
# Processing Record 76 | Klaksvík
# Processing Record 77 | Bathsheba
# Processing Record 78 | Chabahar
# Processing Record 79 | Kalaīkunda
# Processing Record 80 | Upernavik
# Processing Record 81 | Deputatsky
# City not found. Skipping...
# Processing Record 82 | Hong Kong
# Processing Record 83 | Dryden
# City not found. Skipping...
# Processing Record 84 | Ottawa
# Processing Record 85 | Lorengau
# Processing Record 86 | Nikolskoye
# Processing Record 87 | Lebu
# Processing Record 88 | Kharp
# Processing Record 89 | Carnarvon
# Processing Record 90 | Chernyshevskiy
# Processing Record 91 | Miandrivazo
# Processing Record 92 | Igarka
# City not found. Skipping...
# Processing Record 93 | Puerto Ayora
# Processing Record 94 | Anadyr
# Processing Record 95 | Andenes
# Processing Record 96 | Helong
# Processing Record 97 | Ketchikan
# Processing Record 98 | Tuktoyaktuk
# Processing Record 99 | Yellowknife
# Processing Record 100 | Tondi
# Processing Record 101 | Saint-Philippe
# Processing Record 102 | Lagoa
# Processing Record 103 | Hofn
# Processing Record 104 | Nishihara
# City not found. Skipping...
# Processing Record 105 | Saryg-Sep
# Processing Record 106 | Ponta do Sol
# Processing Record 107 | Airai
# Processing Record 108 | Cabo San Lucas
# Processing Record 109 | Giyani
# Processing Record 110 | Alta Floresta
# Processing Record 111 | Vestmannaeyjar
# Processing Record 112 | Chui
# Processing Record 113 | Kaeo
# Processing Record 114 | Kaitangata
# Processing Record 115 | Fortuna
# Processing Record 116 | Morgan City
# City not found. Skipping...
# Processing Record 117 | Quelimane
# City not found. Skipping...
# Processing Record 118 | Castro
# Processing Record 119 | Nuquí
# Processing Record 120 | Inuvik
# Processing Record 121 | Bredasdorp
# Processing Record 122 | Clyde River
# Processing Record 123 | Babstovo
# Processing Record 124 | Port Elizabeth
# Processing Record 125 | Egvekinot
# Processing Record 126 | New Norfolk
# Processing Record 127 | San Juan de los Morros
# Processing Record 128 | Saint George
# Processing Record 129 | Midland
# Processing Record 130 | Nanortalik
# City not found. Skipping...
# Processing Record 131 | Qaanaaq
# Processing Record 132 | Kastamonu Province
# Processing Record 133 | Ostrovnoy
# Processing Record 134 | Inongo
# City not found. Skipping...
# Processing Record 135 | Bay Roberts
# Processing Record 136 | Amurzet
# Processing Record 137 | Srīvardhan
# Processing Record 138 | Birin
# Processing Record 139 | Karatau
# City not found. Skipping...
# Processing Record 140 | Magaria
# Processing Record 141 | Agadez
# Processing Record 142 | Muisne
# Processing Record 143 | Caucayá
# Processing Record 144 | Grindavik
# Processing Record 145 | Taoudenni
# Processing Record 146 | Norman Wells
# Processing Record 147 | Tiksi
# Processing Record 148 | Benguela
# Processing Record 149 | Vilyaka
# Processing Record 150 | Kahului
# Processing Record 151 | Butaritari
# Processing Record 152 | Ganzhou
# Processing Record 153 | Shingū
# Processing Record 154 | Saint-Augustin
# Processing Record 155 | Dingle
# City not found. Skipping...
# Processing Record 156 | Kiryat Gat
# Processing Record 157 | Riberalta
# City not found. Skipping...
# Processing Record 158 | Longyearbyen
# Processing Record 159 | Rudnogorsk
# Processing Record 160 | Bantry
# Processing Record 161 | Hulst
# Processing Record 162 | Kangaatsiaq
# Processing Record 163 | Jalu
# Processing Record 164 | Khorramshahr
# Processing Record 165 | Koslan
# Processing Record 166 | Paracuru
# Processing Record 167 | Lüderitz
# Processing Record 168 | Kampot
# Processing Record 169 | Alekseyevsk
# Processing Record 170 | Richards Bay
# Processing Record 171 | Mont-Dore
# Processing Record 172 | Torbay
# Processing Record 173 | São João da Barra
# Processing Record 174 | Dukat
# Processing Record 175 | Cockburn Town
# Processing Record 176 | Saskylakh
# Processing Record 177 | Killybegs
# City not found. Skipping...
# Processing Record 178 | Eydhafushi
# Processing Record 179 | San Quintín
# Processing Record 180 | La Ronge
# Processing Record 181 | Ribeira Grande
# Processing Record 182 | Kālpi
# Processing Record 183 | Pevek
# Processing Record 184 | Kruisfontein
# Processing Record 185 | Boa Vista
# Processing Record 186 | Muhafazat Lahij
# Processing Record 187 | Yangi Marg`ilon
# Processing Record 188 | Hadishahr
# Processing Record 189 | Mattru
# Processing Record 190 | Edd
# Processing Record 191 | Santa Maria
# Processing Record 192 | Leningradskiy
# Processing Record 193 | Katsuura
# Processing Record 194 | Redmond
# Processing Record 195 | Zhangye
# Processing Record 196 | Along
# Processing Record 197 | Arrondissement du Havre
# Processing Record 198 | Hanzhong
# City not found. Skipping...
# Processing Record 199 | Cherskiy
# Processing Record 200 | Ust-Tsilma
# Processing Record 201 | Carballo
# Processing Record 202 | Humboldt
# Processing Record 203 | Pitiquito
# Processing Record 204 | Mastic Beach
# Processing Record 205 | Santa Isabel
# Processing Record 206 | Egersund
# Processing Record 207 | Iglino
# Processing Record 208 | Araouane
# City not found. Skipping...
# Processing Record 209 | Alice Springs
# Processing Record 210 | Thompson
# Processing Record 211 | Yanino Vtoroye
# Processing Record 212 | Kirkland Lake
# Processing Record 213 | Caravelas
# Processing Record 214 | Iralaya
# Processing Record 215 | Kefamenanu
# Processing Record 216 | Juan de Ayolas
# Processing Record 217 | Sonoita
# City not found. Skipping...
# Processing Record 218 | Santa Vitória do Palmar
# Processing Record 219 | Itarema
# Processing Record 220 | Kulhudhuffushi
# Processing Record 221 | Belūsovka
# Processing Record 222 | Narsaq
# Processing Record 223 | Pitimbu
# Processing Record 224 | Qingdao
# Processing Record 225 | Strelka
# Processing Record 226 | Saldanha
# Processing Record 227 | Winnemucca
# Processing Record 228 | Beloha
# Processing Record 229 | Okhotsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 230 | Innisfail
# Processing Record 231 | Sturgeon Bay
# Processing Record 232 | Port Lincoln
# Processing Record 233 | Tuy Hoa
# Processing Record 234 | Nizwá
# Processing Record 235 | Laas
# City not found. Skipping...
# Processing Record 236 | Palmer
# City not found. Skipping...
# Processing Record 237 | Paranaguá
# Processing Record 238 | Linxia Chengguanzhen
# City not found. Skipping...
# Processing Record 239 | Kyren
# Processing Record 240 | Nanga Eboko
# Processing Record 241 | Horsham
# Processing Record 242 | Rome
# Processing Record 243 | Houma
# Processing Record 244 | Severo-Kuril'sk
# Processing Record 245 | Turukhansk
# Processing Record 246 | Santa Cruz de La Palma
# Processing Record 247 | Tete
# Processing Record 248 | Tual
# Processing Record 249 | Puerto Colombia
# Processing Record 250 | Sterling
# Processing Record 251 | Srednekolymsk
# Processing Record 252 | Balta
# Processing Record 253 | Baryatino
# Processing Record 254 | Pachperwa
# Processing Record 255 | Batī
# Processing Record 256 | Plettenberg Bay
# Processing Record 257 | Sabang
# Processing Record 258 | Vanderhoof
# Processing Record 259 | Tuatapere
# Processing Record 260 | Linfen
# Processing Record 261 | Esperance
# Processing Record 262 | Hjelset
# Processing Record 263 | Oodweyne
# City not found. Skipping...
# Processing Record 264 | Bonavista
# Processing Record 265 | Ous
# Processing Record 266 | Morondava
# Processing Record 267 | Doka
# Processing Record 268 | Karratha
# Processing Record 269 | Jumla
# Processing Record 270 | Fuerte Olimpo
# Processing Record 271 | Smithers
# Processing Record 272 | Ruwi
# Processing Record 273 | Santo Tomas
# Processing Record 274 | Kemijärvi
# Processing Record 275 | Karlovo
# Processing Record 276 | Vestmanna
# Processing Record 277 | Tshikapa
# Processing Record 278 | Margate
# Processing Record 279 | Rabo de Peixe
# Processing Record 280 | Jurm
# Processing Record 281 | Huarmey
# Processing Record 282 | Padang
# Processing Record 283 | Salalah
# Processing Record 284 | Sitka
# City not found. Skipping...
# Processing Record 285 | La Romana
# City not found. Skipping...
# Processing Record 286 | Araci
# Processing Record 287 | Port Hedland
# Processing Record 288 | Fare
# Processing Record 289 | College
# Processing Record 290 | Manokwari
# Processing Record 291 | Novosheshminsk
# Processing Record 292 | Vila Franca do Campo
# Processing Record 293 | Coruripe
# Processing Record 294 | Colares
# Processing Record 295 | Ricardo Palma
# Processing Record 296 | Nome
# Processing Record 297 | Waipawa
# Processing Record 298 | Dzhebariki-Khaya
# Processing Record 299 | Brawley
# Processing Record 300 | San Policarpo
# Processing Record 301 | Beringovskiy
# Processing Record 302 | Paamiut
# Processing Record 303 | Sola
# Processing Record 304 | Sisimiut
# Processing Record 305 | Lavrentiya
# Processing Record 306 | Sept-Îles
# Processing Record 307 | Bama
# Processing Record 308 | Nemuro
# Processing Record 309 | Turaif
# Processing Record 310 | Sambava
# Processing Record 311 | Waingapu
# Processing Record 312 | Saint Paul Harbor
# Processing Record 313 | Danilov
# Processing Record 314 | El Limon
# Processing Record 315 | Malindi
# Processing Record 316 | Geraldton
# Processing Record 317 | Husavik
# Processing Record 318 | Hasaki
# Processing Record 319 | Savannah Bight
# Processing Record 320 | Bilma
# Processing Record 321 | Itamaracá
# Processing Record 322 | Abensberg
# Processing Record 323 | Souillac
# Processing Record 324 | Radeče
# City not found. Skipping...
# Processing Record 325 | Constitución
# Processing Record 326 | Mount Gambier
# Processing Record 327 | Māngrol
# Processing Record 328 | Takoradze
# Processing Record 329 | Moundsville
# Processing Record 330 | Kaka
# Processing Record 331 | Viedma
# Processing Record 332 | Brownwood
# Processing Record 333 | Ankpa
# Processing Record 334 | Ashland
# Processing Record 335 | Aykhal
# Processing Record 336 | Matagami
# Processing Record 337 | Fuzhou
# Processing Record 338 | Kuril'sk
# Processing Record 339 | Kavaratti
# Processing Record 340 | Štíty
# Processing Record 341 | Yar-Sale
# Processing Record 342 | Mayumba
# Processing Record 343 | Samarai
# Processing Record 344 | Mtwara
# Processing Record 345 | Lewiston
# Processing Record 346 | Gogrial
# Processing Record 347 | Juneau
# Processing Record 348 | Yining
# Processing Record 349 | Bodden Town
# Processing Record 350 | Valparaíso
# Processing Record 351 | Zeya
# Processing Record 352 | Mineros
# Processing Record 353 | Tosya
# Processing Record 354 | San Juan
# Processing Record 355 | Puerto Madero
# Processing Record 356 | Soe
# Processing Record 357 | Provideniya
# Processing Record 358 | Lima
# Processing Record 359 | Piombino
# Processing Record 360 | San Patricio
# Processing Record 361 | Shizunai-furukawachō
# Processing Record 362 | Kem'
# Processing Record 363 | Forbes
# Processing Record 364 | Carlsbad
# City not found. Skipping...
# Processing Record 365 | Warmbad
# Processing Record 366 | Dzilam González
# Processing Record 367 | Keuruu
# Processing Record 368 | Zhigalovo
# Processing Record 369 | Bulungu
# Processing Record 370 | Sinnamary
# City not found. Skipping...
# Processing Record 371 | Córdoba
# Processing Record 372 | Alghero
# Processing Record 373 | Gushikawa
# Processing Record 374 | Xining
# Processing Record 375 | Guerrero Negro
# Processing Record 376 | Qalyub
# Processing Record 377 | Seydişehir
# Processing Record 378 | Bhadrapur
# Processing Record 379 | Roebourne
# Processing Record 380 | Baruun-Urt
# City not found. Skipping...
# Processing Record 381 | Morris
# Processing Record 382 | Verkhnyaya Inta
# Processing Record 383 | Penukonda
# Processing Record 384 | Ryōtsu-minato
# Processing Record 385 | Nelson Bay
# Processing Record 386 | Pinehurst
# City not found. Skipping...
# Processing Record 387 | Mahébourg
# Processing Record 388 | Yenagoa
# Processing Record 389 | Kushima
# Processing Record 390 | Barabai
# City not found. Skipping...
# Processing Record 391 | The Valley
# Processing Record 392 | Gawler
# Processing Record 393 | Tokur
# Processing Record 394 | Shellbrook
# Processing Record 395 | Selma
# Processing Record 396 | Comodoro Rivadavia
# Processing Record 397 | Monteagudo
# Processing Record 398 | Vostok
# Processing Record 399 | Ballina
# Processing Record 400 | El Batey
# Processing Record 401 | Esso
# Processing Record 402 | Kīhei
# Processing Record 403 | Vanavara
# Processing Record 404 | Brockville
# Processing Record 405 | Labuhan
# Processing Record 406 | Palekastro
# Processing Record 407 | Forsytheganj
# Processing Record 408 | Noumea
# Processing Record 409 | Kearney
# Processing Record 410 | Ubari
# Processing Record 411 | Tārānagar
# Processing Record 412 | Ongandjera
# Processing Record 413 | Coxim
# Processing Record 414 | Petropavlovsk-Kamchatskiy
# Processing Record 415 | Dunmore Town
# Processing Record 416 | Djibo
# Processing Record 417 | Ixtapa
# Processing Record 418 | Pangnirtung
# Processing Record 419 | Tsiroanomandidy
# City not found. Skipping...
# Processing Record 420 | Bayjī
# Processing Record 421 | Florianópolis
# Processing Record 422 | Lata
# Processing Record 423 | Visby
# Processing Record 424 | Cam Ranh
# Processing Record 425 | Kyra
# Processing Record 426 | Hervey Bay
# Processing Record 427 | Ancud
# Processing Record 428 | Pacific Grove
# Processing Record 429 | Nyurba
# Processing Record 430 | Fukuechō
# Processing Record 431 | Øksfjord
# Processing Record 432 | Fort-Shevchenko
# Processing Record 433 | Mauá
# Processing Record 434 | Harrisonburg
# Processing Record 435 | Butler
# Processing Record 436 | Makakilo City
# Processing Record 437 | Selikhino
# Processing Record 438 | Tall Kayf
# Processing Record 439 | Leh
# Processing Record 440 | Ondangwa
# Processing Record 441 | Ilulissat
# Processing Record 442 | Andapa
# Processing Record 443 | Port Blair
# Processing Record 444 | Bengkulu
# Processing Record 445 | Vurğun
# City not found. Skipping...
# Processing Record 446 | Marzuq
# Processing Record 447 | Shimoda
# Processing Record 448 | Khandagayty
# Processing Record 449 | Dongsheng
# Processing Record 450 | Magadan
# Processing Record 451 | Kawalu
# Processing Record 452 | Ust'-Kulom
# Processing Record 453 | Miami
# Processing Record 454 | Saint-Pierre
# Processing Record 455 | Jizan
# City not found. Skipping...
# Processing Record 456 | Clearwater
# Processing Record 457 | Mezen'
# Processing Record 458 | Mackay
# Processing Record 459 | Roald
# Processing Record 460 | Ylöjärvi
# Processing Record 461 | Lamu
# Processing Record 462 | Harper
# Processing Record 463 | Ringe
# Processing Record 464 | Balyqshy
# Processing Record 465 | Toktogul
# Processing Record 466 | Ruteng
# Processing Record 467 | Qaqortoq
# Processing Record 468 | São Filipe
# Processing Record 469 | Nhulunbuy
# Processing Record 470 | Östersund
# Processing Record 471 | Parrita
# City not found. Skipping...
# Processing Record 472 | Bireun
# Processing Record 473 | Todos Santos
# Processing Record 474 | Tambura
# Processing Record 475 | Chirongui
# Processing Record 476 | Bentiu
# City not found. Skipping...
# Processing Record 477 | Sirte
# Processing Record 478 | Boende
# Processing Record 479 | Dunedin
# Processing Record 480 | Bubaque
# Processing Record 481 | Aubenas
# Processing Record 482 | Lázaro Cárdenas
# Processing Record 483 | Onega
# Processing Record 484 | Media Luna
# Processing Record 485 | Sapucaí
# Processing Record 486 | Urmia
# Processing Record 487 | Channel-Port aux Basques
# Processing Record 488 | Tura
# Processing Record 489 | Uvinza
# Processing Record 490 | Enterprise
# Processing Record 491 | Departamento de Maldonado
# Processing Record 492 | Tilichiki
# Processing Record 493 | Valdivia
# Processing Record 494 | Troitskiy
# Processing Record 495 | Khuzdar
# Processing Record 496 | Zima
# Processing Record 497 | Jinka
# City not found. Skipping...
# Processing Record 498 | Mandalgovi
# Processing Record 499 | Bailén
# Processing Record 500 | Hirara
# Processing Record 501 | Krasnoturansk
# Processing Record 502 | Riyadh
# Processing Record 503 | Kouango
# Processing Record 504 | Caála
# Processing Record 505 | Marawi
# Processing Record 506 | Pahrump
# Processing Record 507 | Mabaruma
# Processing Record 508 | Benghazi
# Processing Record 509 | Sohag
# Processing Record 510 | Mexico
# Processing Record 511 | Najrān
# Processing Record 512 | Huilong
# Processing Record 513 | Khandyga
# Processing Record 514 | Datong
# Processing Record 515 | Malbork
# Processing Record 516 | Tigil'
# Processing Record 517 | Mt. Pleasant
# Processing Record 518 | Bukachacha
# Processing Record 519 | Lipari
# Processing Record 520 | Poum
# Processing Record 521 | Vila do Maio
# Processing Record 522 | Kingisepp
# Processing Record 523 | Eskhar
# Processing Record 524 | Atar
# Processing Record 525 | Seoul
# Processing Record 526 | Sarakhs
# Processing Record 527 | Eureka
# Processing Record 528 | Makkah al Mukarramah
# Processing Record 529 | Leshukonskoye
# Processing Record 530 | Batamshinskiy
# Processing Record 531 | Jiayuguan City
# Processing Record 532 | Kamenolomni
# Processing Record 533 | Mlonggo
# City not found. Skipping...
# Processing Record 534 | Ishigaki
# Processing Record 535 | Tygda
# Processing Record 536 | Praia
# Processing Record 537 | Los Llanos de Aridane
# Processing Record 538 | Hailar
# City not found. Skipping...
# Processing Record 539 | Camopi
# Processing Record 540 | Skole
# Processing Record 541 | Ust'-Ishim
# Processing Record 542 | Tsimmerbude
# Processing Record 543 | Rundu
# Processing Record 544 | Milton Keynes
# Processing Record 545 | Shihezi
# Processing Record 546 | Marfino
# Processing Record 547 | Zhigansk
# Processing Record 548 | Agüimes
# Processing Record 549 | Ponta Delgada
# Processing Record 550 | Dhārchula
# Processing Record 551 | Haines Junction
# City not found. Skipping...
# Processing Record 552 | San Francisco
# Processing Record 553 | Launceston
# Processing Record 554 | ‘Āhuimanu
# Processing Record 555 | Qarayeri
# City not found. Skipping...
# Processing Record 556 | Ambilobe
# City not found. Skipping...
# Processing Record 557 | Mongomo
# Processing Record 558 | Bilibino
# Processing Record 559 | Hobyo
# Processing Record 560 | Laguna
# Processing Record 561 | Bukama
# Processing Record 562 | Saint-Paul
# Processing Record 563 | Northam
# Processing Record 564 | Vanimo
# Processing Record 565 | Varhaug
# Processing Record 566 | Sioux Lookout
# Processing Record 567 | Raudeberg
# Processing Record 568 | Portland
# Processing Record 569 | Malanje
# Processing Record 570 | Olafsvik
# Processing Record 571 | Okha
# Processing Record 572 | Emerald
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a DataFrame from Cities, Latitude, Longitude, Temperature, Humidity, Cloudiness & Wind Speed
weather_dict = {
    "City": city_name,
    "Country": country,
    "Date": date,
    "Latitude": latitude,
    "Longitude": longitude,
    "Max Temperature": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               572
# Country            572
# Date               572
# Latitude           572
# Longitude          572
# Max Temperature    572
# Humidity           572
# Cloudiness         572
# Wind Speed         572
# dtype: int64

# %%
# Display DataFrame
weather_data.head()
# Out:
#             City Country        Date  Latitude  Longitude  Max Temperature  \
# 0         Barrow      US  1604801029     71.29    -156.79             30.2
# 1       Guérande      FR  1604801030     47.33      -2.43             59.0
# 2        Ushuaia      AR  1604800886    -54.80     -68.30             57.2
# 3    George Town      MY  1604801030      5.41     100.34             82.4
# 4  Prince Rupert      CA  1604801030     54.32    -130.32             42.8
#
#    Humidity  Cloudiness  Wind Speed
# 0        92          90       23.04
# 1        93          90        3.36
# 2        44          20       14.99
# 3        83          20        4.70
# 4        64           1        6.93

# %%
weather_data.describe()
# Out:
#                Date    Latitude   Longitude  Max Temperature    Humidity  \
# count  5.720000e+02  572.000000  572.000000       572.000000  572.000000
# mean   1.604801e+09   22.977028   17.802395        56.139266   74.323427
# std    1.997815e+02   32.837143   89.448190        22.533229   19.325816
# min    1.604800e+09  -54.800000 -179.170000       -14.670000   10.000000
# 25%    1.604801e+09   -3.762500  -59.235000        40.712500   63.000000
# 50%    1.604801e+09   29.650000   23.440000        60.405000   79.000000
# 75%    1.604801e+09   50.147500   95.732500        75.010000   89.000000
# max    1.604801e+09   78.220000  179.320000        96.800000  100.000000
#
#        Cloudiness  Wind Speed
# count  572.000000  572.000000
# mean    47.347902    7.760070
# std     40.517056    6.001619
# min      0.000000    0.290000
# 25%      1.000000    3.360000
# 50%     41.000000    5.990000
# 75%     90.000000   10.405000
# max    100.000000   36.910000

# %%
#Remove cities where Humidity > 100%
humid_cities = weather_data["City"].loc[weather_data["Humidity"] > 100].count()
if humid_cities > 0:
    weather_data = city_df.loc[weather_data["Humidity"] <= 100]
weather_data
# Out:
#               City Country        Date  Latitude  Longitude  Max Temperature  \
# 0           Barrow      US  1604801029     71.29    -156.79            30.20
# 1         Guérande      FR  1604801030     47.33      -2.43            59.00
# 2          Ushuaia      AR  1604800886    -54.80     -68.30            57.20
# 3      George Town      MY  1604801030      5.41     100.34            82.40
# 4    Prince Rupert      CA  1604801030     54.32    -130.32            42.80
# ..             ...     ...         ...       ...        ...              ...
# 567       Portland      US  1604800404     45.52    -122.68            43.00
# 568        Malanje      AO  1604800910     -9.54      16.34            65.89
# 569       Olafsvik      IS  1604800672     64.89     -23.71            39.85
# 570           Okha      RU  1604800788     53.57     142.95            27.55
# 571        Emerald      AU  1604801147    -23.53     148.17            79.00
#
#      Humidity  Cloudiness  Wind Speed
# 0          92          90       23.04
# 1          93          90        3.36
# 2          44          20       14.99
# 3          83          20        4.70
# 4          64           1        6.93
# ..        ...         ...         ...
# 567        87          99        1.99
# 568        99         100        4.88
# 569        72          30       24.25
# 570        89         100       13.56
# 571        61          75       16.11
#
# [572 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors="red", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
plt.title(f"City Latitude vs. Max Temperature ({plot_date})")
x_lat = weather_data['Latitude']
y_temp = weather_data['Max Temperature']
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Max_Temperature.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], facecolors="green", marker="o", edgecolor="black")
# Incorporate Other Graph Properties
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
plt.title(f"City Latitude vs. Humidity ({plot_date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Humidity.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
from datetime import datetime
dt = int(date[0])
plot_date = datetime.fromtimestamp(dt).strftime('%y/%m/%d')
plt.title(f"City Latitude vs. Cloudiness ({plot_date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Cloudiness.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors="yellow", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Wind Speed (02/01/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Wind_Speed.png")

# Show Plot
plt.show()

# %% [markdown]
# #  Linear Regression

# %%
# dependencies
import scipy.stats as st

# %% [markdown]
# # Create data frame for northern and southern hemispheres

# %%
# northern hemisphere data frame
north_df = weather_data[weather_data["Latitude"] >= 0]
north_df
# Out:
#               City Country        Date  Latitude  Longitude  Max Temperature  \
# 0           Barrow      US  1604801029     71.29    -156.79            30.20
# 1         Guérande      FR  1604801030     47.33      -2.43            59.00
# 3      George Town      MY  1604801030      5.41     100.34            82.40
# 4    Prince Rupert      CA  1604801030     54.32    -130.32            42.80
# 6           Lompoc      US  1604800488     34.64    -120.46            53.60
# ..             ...     ...         ...       ...        ...              ...
# 565  Sioux Lookout      CA  1604800697     50.10     -91.92            32.00
# 566      Raudeberg      NO  1604801146     61.99       5.14            46.40
# 567       Portland      US  1604800404     45.52    -122.68            43.00
# 569       Olafsvik      IS  1604800672     64.89     -23.71            39.85
# 570           Okha      RU  1604800788     53.57     142.95            27.55
#
#      Humidity  Cloudiness  Wind Speed
# 0          92          90       23.04
# 1          93          90        3.36
# 3          83          20        4.70
# 4          64           1        6.93
# 6          76          40        8.05
# ..        ...         ...         ...
# 565        93          90        6.93
# 566       100         100        5.82
# 567        87          99        1.99
# 569        72          30       24.25
# 570        89         100       13.56
#
# [411 rows x 9 columns]

# %%
# southern hemisphere data frame
south_df = weather_data[weather_data["Latitude"] < 0]
south_df
# Out:
#               City Country        Date  Latitude  Longitude  Max Temperature  \
# 2          Ushuaia      AR  1604800886    -54.80     -68.30            57.20
# 5     Punta Arenas      CL  1604800433    -53.15     -70.92            51.80
# 7          Illapel      CL  1604801031    -31.63     -71.17            56.89
# 8    Mar del Plata      AR  1604800977    -38.00     -57.56            62.01
# 9           Faanui      PF  1604801031    -16.48    -151.75            79.45
# ..             ...     ...         ...       ...        ...              ...
# 560         Bukama      CD  1604801145     -9.20      25.85            70.79
# 561     Saint-Paul      RE  1604801145    -21.01      55.27            71.60
# 563         Vanimo      PG  1604801145     -2.67     141.30            77.86
# 568        Malanje      AO  1604800910     -9.54      16.34            65.89
# 571        Emerald      AU  1604801147    -23.53     148.17            79.00
#
#      Humidity  Cloudiness  Wind Speed
# 2          44          20       14.99
# 5          71          40       31.09
# 7          74           0        0.85
# 8          93          40        4.70
# 9          75         100       10.94
# ..        ...         ...         ...
# 560        89          23        0.65
# 561        68          75       11.41
# 563        85         100        4.76
# 568        99         100        4.88
# 571        61          75       16.11
#
# [161 rows x 9 columns]

# %% [markdown]
# # Northern Hemisphere - Max Temperature vs Latitude

# %%
north_x_lat = north_df["Latitude"]
north_y_temp = north_df["Max Temperature"]

nt_corr_coef = round(st.pearsonr(north_x_lat, north_y_temp)[0],2)
print(f"correlation coefficient: {nt_corr_coef}")

n_temp = st.linregress(north_x_lat, north_y_temp)
print(f"The r-value is {round(n_temp.rvalue,2)}")
# Out:
# correlation coefficient: -0.86
# The r-value is -0.86

# %%
#create equation of line
line = n_temp.slope * north_x_lat + n_temp.intercept
line_eq = f"y = {round(n_temp.slope,2)}x + {round(n_temp.intercept,2)}"

# plot linear model on top of scatter plot
fig, ax = plt.subplots(figsize=(7,7))
ax.set_autoscale_on(True)
ax.scatter(north_x_lat, north_y_temp, marker='.', facecolors="blue", edgecolors="blue")
plt.plot(north_x_lat, line, 'r-')
plt.title(f"Northern Hemisphere - Max Temp vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, (0,0), fontsize=12, color="red")

file = os.path.join("../Images/North_lat_temp.png")
plt.savefig(file)

# %% [markdown]
# # Southern Hemisphere - Max Temperature vs Latitude

# %%
south_x_lat = south_df["Latitude"]
south_y_temp = south_df["Max Temperature"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_temp)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

s_temp = st.linregress(south_x_lat, south_y_temp)
print(f"The r-value is {s_temp.rvalue}")
# Out:
# correlation coefficient: 0.64
# The r-value is 0.6388546079135501

# %%
#create equation of line
line = s_temp.slope * south_x_lat + s_temp.intercept
line_eq = f"y = {round(s_temp.slope,2)}x + {round(s_temp.intercept,2)}"

# plot linear model on top of scatter plot
fig, axs = plt.subplots(figsize=(7,7))
axs.set_autoscale_on(True)
axs.scatter(south_x_lat, south_y_temp, marker='.', facecolors="blue", edgecolors="blue")
plt.plot(south_x_lat, line, 'r-')
plt.title(f"Southern Hemisphere - Max Temp vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.annotate(line_eq, (-50,80), fontsize=12, color="red")

file = os.path.join("../Images/South_lat_temp.png")
plt.savefig(file)

# %% [markdown]
# # Northern Hemisphere - Humidity (%) vs Latitude

# %%
north_y_hum = north_df["Humidity"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_hum)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

n_humid = st.linregress(north_x_lat, north_y_hum)
print(f"The r-value is {n_humid.rvalue}")
# Out:
# correlation coefficient: 0.33
# The r-value is 0.3298754418031718

# %%
#create equation of line
line = n_humid.slope * north_x_lat + n_humid.intercept
line_eq = f"y = {round(n_humid.slope,2)}x + {round(n_humid.intercept,2)}"

# plot linear model on top of scatter plot
fig, nh = plt.subplots(figsize=(7,7))
nh.set_autoscale_on(True)
nh.scatter(north_x_lat, north_y_hum, marker='.', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'r-')
plt.title(f"Northern Hemisphere - Humidity (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq, (50,20), fontsize=12, color="red")

file = os.path.join("../Images/North_lat_humid.png")
plt.savefig(file)

# %% [markdown]
# # Southern Hemisphere - Humidity (%) vs Latitude

# %%
south_y_hum = south_df["Humidity"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_hum)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

s_humid = st.linregress(south_x_lat, south_y_hum)
print(f"The r-value is {s_humid.rvalue}")
# Out:
# correlation coefficient: 0.15
# The r-value is 0.15097723943312502

# %%
#create equation of line
line = s_humid.slope * south_x_lat + s_humid.intercept
line_eq = f"y = {round(s_humid.slope,2)}x + {round(s_humid.intercept,2)}"

# plot linear model on top of scatter plot
fig, sh = plt.subplots(figsize=(7,7))
sh.set_autoscale_on(True)
sh.scatter(south_x_lat, south_y_hum, marker='.', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'r-')
plt.title(f"Southern Hemisphere - Humidity (%) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.annotate(line_eq, (-50,10), fontsize=12, color="red")

file = os.path.join("../Images/South_lat_humid.png")
plt.savefig(file)

# %% [markdown]
# # Northern Hemisphere - Wind Speed (mph) vs Latitude

# %%
north_y_wind = north_df["Wind Speed"]

n_corr_coef = round(st.pearsonr(north_x_lat, north_y_wind)[0],2)
print(f"correlation coefficient: {n_corr_coef}")

north_wind = st.linregress(north_x_lat, north_y_wind)
print(f"The r-value is {north_wind.rvalue}")
# Out:
# correlation coefficient: 0.07
# The r-value is 0.06819669990683862

# %%
#create equation of line
line = north_wind.slope * north_x_lat + north_wind.intercept
line_eq = f"y = {round(north_wind.slope,2)}x + {round(north_wind.intercept,2)}"

# plot linear model on top of scatter plot
fig, nw = plt.subplots(figsize=(7,7))
nw.set_autoscale_on(True)
nw.scatter(north_x_lat, north_y_wind, marker='.', facecolors="green", edgecolors="green")
plt.plot(north_x_lat, line, 'r-')
plt.title(f"Northern Hemisphere - Wind Speed (mph) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq, (0, 30), fontsize=12, color="red")

file = os.path.join("../Images/North_lat_wind.png")
plt.savefig(file)

# %% [markdown]
# # Southern Hemisphere - Wind Speed (mph) vs Latitude

# %%
south_y_wind = south_df["Wind Speed"]

s_corr_coef = round(st.pearsonr(south_x_lat, south_y_wind)[0],2)
print(f"correlation coefficient: {s_corr_coef}")

south_wind = st.linregress(south_x_lat, south_y_wind)
print(f"The r-value is {south_wind.rvalue}")
# Out:
# correlation coefficient: -0.32
# The r-value is -0.32268614169313475

# %%
#create equation of line
line = south_wind.slope * south_x_lat + south_wind.intercept
line_eq = f"y = {round(south_wind.slope,2)}x + {round(south_wind.intercept,2)}"

# plot linear model on top of scatter plot
fig, sw = plt.subplots(figsize=(7,7))
sw.set_autoscale_on(True)
sw.scatter(south_x_lat, south_y_wind, marker='.', facecolors="green", edgecolors="green")
plt.plot(south_x_lat, line, 'r-')
plt.title(f"Southern Hemisphere - Wind Speed (mph) vs Latitude ({plot_date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.annotate(line_eq, (-55, 4), fontsize=12, color="red")

file = os.path.join("../Images/South_lat_wind.png")
plt.savefig(file)

# %% [markdown]
# # Temperature (F) vs Latitude

# %%
colors = y_temp

fig, ax = plt.subplots(figsize=(10,8))
ax.set_autoscale_on(True)
plt.scatter(x_lat,y_temp, c=colors)
colorbar = plt.colorbar()
colorbar.ax.set_ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title("Temperature (F) vs Latitude")
plt.grid()

file = os.path.join("../Images/heatmap.png")
plt.savefig(file)
