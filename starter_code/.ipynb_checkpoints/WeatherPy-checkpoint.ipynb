# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observable Trends
# 1.Collecting weather data from 559 random and diverse cities around the world using the OpenWeatherMap API,the data illustrated maximum temperature(in Fahrenheit),humidity(%),cloudiness(%)and wind speed(in mph)with the corresponding city,and with respect to the geo-coordinate,Latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import os

# !pip install citipy

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.8/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.8/site-packages (from citipy) (0.16)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# create url
# Get Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

weather_response = requests.get(query_url + city)
weather_json = weather_response.json()
print(json.dumps(weather_json, indent=4))
# Out:
# {
#     "coord": {
#         "lon": 45.01,
#         "lat": 10.44
#     },
#     "weather": [
#         {
#             "id": 800,
#             "main": "Clear",
#             "description": "clear sky",
#             "icon": "01d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 82.02,
#         "feels_like": 84.97,
#         "temp_min": 82.02,
#         "temp_max": 82.02,
#         "pressure": 1016,
#         "humidity": 53,
#         "sea_level": 1016,
#         "grnd_level": 1016
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 2.77,
#         "deg": 33
#     },
#     "clouds": {
#         "all": 3
#     },
#     "dt": 1604730424,
#     "sys": {
#         "country": "SO",
#         "sunrise": 1604717554,
#         "sunset": 1604759687
#     },
#     "timezone": 10800,
#     "id": 64435,
#     "name": "Berbera",
#     "cod": 200
# }

# %%
print(requests.get(query_url + city))
# Out:
# <Response [200]>

# %%
# Set Up Lists to Hold Reponse Info
city_name = []
country = []
date = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []

# Processing Record Counter Starting a 1
processing_record = 1

# Print Starting Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop Through List of Cities & Perform a Request for Data on Each
for city in cities:

# Exception Handling
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {processing_record} | {city_record}")
        
        # Increase Processing Record Counter by 1 For Each Loop
        processing_record += 1
        
    except:
        print("City not found. Skipping...") 
    continue

# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Mataura
# Processing Record 2 | Cidreira
# Processing Record 3 | Ancud
# Processing Record 4 | Bengkulu
# Processing Record 5 | Norman Wells
# Processing Record 6 | Hilo
# Processing Record 7 | Vaini
# Processing Record 8 | Puerto Ayora
# Processing Record 9 | Kendari
# Processing Record 10 | Ushuaia
# Processing Record 11 | Vila do Maio
# City not found. Skipping...
# Processing Record 12 | Lavrentiya
# Processing Record 13 | San Felipe
# Processing Record 14 | Busselton
# Processing Record 15 | Cape Town
# Processing Record 16 | Saint-Philippe
# Processing Record 17 | Albany
# Processing Record 18 | Ko Samui
# Processing Record 19 | Punta Arenas
# City not found. Skipping...
# Processing Record 20 | Ubatuba
# Processing Record 21 | Upernavik
# Processing Record 22 | Ngunguru
# Processing Record 23 | Airai
# Processing Record 24 | Rikitea
# Processing Record 25 | Hervey Bay
# Processing Record 26 | Avarua
# Processing Record 27 | Dajal
# Processing Record 28 | Kapaa
# Processing Record 29 | Tiksi
# Processing Record 30 | Churapcha
# Processing Record 31 | Nelson Bay
# Processing Record 32 | Mar del Plata
# Processing Record 33 | Hithadhoo
# Processing Record 34 | Finschhafen
# Processing Record 35 | Bluff
# Processing Record 36 | Yatou
# Processing Record 37 | Longyearbyen
# Processing Record 38 | Esperance
# Processing Record 39 | Saint-Pierre
# Processing Record 40 | Carnarvon
# City not found. Skipping...
# Processing Record 41 | Jamestown
# Processing Record 42 | Saravan
# City not found. Skipping...
# Processing Record 43 | Bambous Virieux
# Processing Record 44 | Kloulklubed
# Processing Record 45 | Blagoyevo
# Processing Record 46 | Sept-Îles
# Processing Record 47 | Meulaboh
# Processing Record 48 | Biak
# Processing Record 49 | Province of Mantua
# Processing Record 50 | Fairbanks
# Processing Record 51 | Leer
# City not found. Skipping...
# Processing Record 52 | Yar-Sale
# Processing Record 53 | Kahului
# Processing Record 54 | Cayenne
# Processing Record 55 | Dvinskoy Bereznik
# Processing Record 56 | Boromo
# Processing Record 57 | Waingapu
# Processing Record 58 | Kama
# Processing Record 59 | Atuona
# City not found. Skipping...
# Processing Record 60 | East London
# Processing Record 61 | Siyabuswa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 62 | Sisimiut
# Processing Record 63 | Valladolid
# Processing Record 64 | Nikolskoye
# Processing Record 65 | São José da Coroa Grande
# Processing Record 66 | Saint George
# Processing Record 67 | Acarí
# Processing Record 68 | High Prairie
# City not found. Skipping...
# Processing Record 69 | Margate
# Processing Record 70 | Zhigansk
# Processing Record 71 | Severnyy
# Processing Record 72 | Bredasdorp
# Processing Record 73 | Hobart
# Processing Record 74 | Chifeng
# Processing Record 75 | Arraial do Cabo
# Processing Record 76 | Waipawa
# Processing Record 77 | Santana
# Processing Record 78 | Safi
# City not found. Skipping...
# Processing Record 79 | Lebu
# Processing Record 80 | Eyrarbakki
# City not found. Skipping...
# Processing Record 81 | West Bay
# Processing Record 82 | Takaka
# Processing Record 83 | Butaritari
# Processing Record 84 | Torbay
# Processing Record 85 | Klaksvík
# City not found. Skipping...
# Processing Record 86 | Barra de Tecoanapa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 87 | Brookhaven
# Processing Record 88 | Aquiraz
# Processing Record 89 | Dikson
# Processing Record 90 | Bereket
# Processing Record 91 | Labytnangi
# Processing Record 92 | Itaituba
# Processing Record 93 | Rechka Vydrino
# Processing Record 94 | Faanui
# Processing Record 95 | Charters Towers
# Processing Record 96 | Sur
# Processing Record 97 | Qaanaaq
# Processing Record 98 | Thompson
# Processing Record 99 | San Juan del Sur
# Processing Record 100 | New Norfolk
# Processing Record 101 | Lerwick
# City not found. Skipping...
# Processing Record 102 | Nyurba
# Processing Record 103 | Ridgecrest
# Processing Record 104 | Sosnogorsk
# City not found. Skipping...
# Processing Record 105 | Tasiilaq
# Processing Record 106 | Talnakh
# Processing Record 107 | Auki
# Processing Record 108 | Le Port
# Processing Record 109 | Catherinas Lust
# Processing Record 110 | Ust-Tsilma
# Processing Record 111 | Wanning
# Processing Record 112 | College
# Processing Record 113 | Barrow
# Processing Record 114 | Sharon
# Processing Record 115 | Pevek
# City not found. Skipping...
# Processing Record 116 | Luwingu
# Processing Record 117 | City of San Pedro
# Processing Record 118 | Kavieng
# Processing Record 119 | Grand Island
# Processing Record 120 | Port Alfred
# Processing Record 121 | Saint Paul Harbor
# Processing Record 122 | Hermanus
# Processing Record 123 | Alberton
# Processing Record 124 | Khatanga
# Processing Record 125 | Batagay
# City not found. Skipping...
# Processing Record 126 | Harindānga
# Processing Record 127 | Hobyo
# City not found. Skipping...
# Processing Record 128 | Inhambane
# Processing Record 129 | Viesca
# Processing Record 130 | Port Hardy
# Processing Record 131 | Aranda de Duero
# Processing Record 132 | Te Anau
# Processing Record 133 | Souillac
# Processing Record 134 | Noumea
# Processing Record 135 | Camacha
# Processing Record 136 | Correntina
# Processing Record 137 | Fukuechō
# Processing Record 138 | Guadalupe y Calvo
# Processing Record 139 | Port-Gentil
# Processing Record 140 | Keskin
# Processing Record 141 | Santa Maria
# Processing Record 142 | Tailai
# Processing Record 143 | Cherskiy
# Processing Record 144 | Anori
# Processing Record 145 | Ribeira Grande
# Processing Record 146 | Kampene
# City not found. Skipping...
# Processing Record 147 | Henties Bay
# Processing Record 148 | Nyagan
# Processing Record 149 | Port Lincoln
# Processing Record 150 | Banda Aceh
# Processing Record 151 | Bentiu
# Processing Record 152 | Naberera
# Processing Record 153 | Pires do Rio
# City not found. Skipping...
# Processing Record 154 | Mahébourg
# Processing Record 155 | Luba
# Processing Record 156 | Ponta do Sol
# Processing Record 157 | Peleduy
# Processing Record 158 | Kiruna
# Processing Record 159 | Razumnoye
# Processing Record 160 | Geraldton
# Processing Record 161 | George Town
# Processing Record 162 | Palmer
# City not found. Skipping...
# Processing Record 163 | Chokurdakh
# Processing Record 164 | Chicama
# Processing Record 165 | Severo-Kuril'sk
# Processing Record 166 | Dunmore Town
# Processing Record 167 | Ratnagiri
# Processing Record 168 | Zeya
# Processing Record 169 | Kawalu
# City not found. Skipping...
# Processing Record 170 | Hirara
# Processing Record 171 | Severobaykal'sk
# Processing Record 172 | Lubango
# Processing Record 173 | Naro-Fominsk
# Processing Record 174 | Coronel Vivida
# Processing Record 175 | Poum
# Processing Record 176 | Kaitangata
# Processing Record 177 | Leningradskiy
# Processing Record 178 | Boa Vista
# City not found. Skipping...
# Processing Record 179 | Emerald
# Processing Record 180 | Saskylakh
# Processing Record 181 | Joshīmath
# Processing Record 182 | Nizhniy Kuranakh
# Processing Record 183 | Japura
# Processing Record 184 | Bathsheba
# Processing Record 185 | Solnechnyy
# Processing Record 186 | Hong Kong
# Processing Record 187 | Laguna
# Processing Record 188 | Pochutla
# Processing Record 189 | Tuktoyaktuk
# Processing Record 190 | Ialibu
# Processing Record 191 | Vardø
# Processing Record 192 | Porto-Novo
# Processing Record 193 | Korla
# Processing Record 194 | Marand
# Processing Record 195 | Winslow
# Processing Record 196 | Marawi
# Processing Record 197 | Iqaluit
# Processing Record 198 | Puerto Baquerizo Moreno
# Processing Record 199 | Cockburn Town
# Processing Record 200 | Nome
# Processing Record 201 | Cururupu
# Processing Record 202 | Kruisfontein
# City not found. Skipping...
# Processing Record 203 | Itapaci
# Processing Record 204 | Kongolo
# Processing Record 205 | Castletown
# Processing Record 206 | Kaeo
# Processing Record 207 | Verkhnevilyuysk
# Processing Record 208 | Yellowknife
# Processing Record 209 | San Patricio
# Processing Record 210 | Dostpur
# Processing Record 211 | Santa Isabel
# Processing Record 212 | Coolum Beach
# Processing Record 213 | Labuhan
# Processing Record 214 | San Cristobal
# Processing Record 215 | Coruripe
# Processing Record 216 | Rocha
# Processing Record 217 | Pacific Grove
# Processing Record 218 | Burnie
# Processing Record 219 | Yulara
# City not found. Skipping...
# Processing Record 220 | Mayumba
# Processing Record 221 | Ucluelet
# Processing Record 222 | Tiznit Province
# Processing Record 223 | Adrar
# City not found. Skipping...
# Processing Record 224 | Port Augusta
# Processing Record 225 | Cantagalo
# Processing Record 226 | Mitsamiouli
# Processing Record 227 | Yumen
# Processing Record 228 | Galesong
# Processing Record 229 | Kuloy
# Processing Record 230 | Bariloche
# Processing Record 231 | Alice Springs
# Processing Record 232 | Arrecife
# Processing Record 233 | Huicungo
# Processing Record 234 | Cabo San Lucas
# Processing Record 235 | Salalah
# Processing Record 236 | Tegul'det
# Processing Record 237 | Hay River
# Processing Record 238 | Castro
# Processing Record 239 | Los Llanos de Aridane
# Processing Record 240 | Bozhou
# Processing Record 241 | Olafsvik
# Processing Record 242 | Abaeté
# Processing Record 243 | Tura
# Processing Record 244 | Port Hedland
# Processing Record 245 | Inta
# Processing Record 246 | Broken Hill
# Processing Record 247 | Soyo
# Processing Record 248 | Sidi Ali
# Processing Record 249 | Ostrovnoy
# Processing Record 250 | Balkanabat
# Processing Record 251 | Kristinehamn
# Processing Record 252 | Karratha
# Processing Record 253 | Casper
# Processing Record 254 | Taree
# Processing Record 255 | Benjamin Constant
# Processing Record 256 | Katsuura
# Processing Record 257 | Nanchang
# Processing Record 258 | Itoman
# Processing Record 259 | Matara
# Processing Record 260 | Hofn
# Processing Record 261 | Vangaindrano
# Processing Record 262 | Birao
# Processing Record 263 | Trairi
# Processing Record 264 | Yangi Marg`ilon
# Processing Record 265 | Russell
# Processing Record 266 | Lundazi
# Processing Record 267 | Chui
# City not found. Skipping...
# Processing Record 268 | Dwārka
# Processing Record 269 | Pangnirtung
# Processing Record 270 | Charter Township of Clinton
# Processing Record 271 | Deputatsky
# Processing Record 272 | Marzuq
# Processing Record 273 | Provideniya
# Processing Record 274 | Bonfim
# Processing Record 275 | Carinhanha
# Processing Record 276 | Thayetmyo
# Processing Record 277 | Andenes
# Processing Record 278 | Touba
# Processing Record 279 | Codrington
# Processing Record 280 | Jiwani
# Processing Record 281 | São Filipe
# Processing Record 282 | Muravlenko
# Processing Record 283 | Bhigvan
# Processing Record 284 | Isangel
# Processing Record 285 | Constitución
# Processing Record 286 | Clyde River
# Processing Record 287 | Buíque
# Processing Record 288 | Västerås
# Processing Record 289 | Kiryat Gat
# Processing Record 290 | Goderich
# Processing Record 291 | Nanortalik
# Processing Record 292 | Tamandaré
# Processing Record 293 | Lata
# Processing Record 294 | Taldan
# Processing Record 295 | Anadyr
# City not found. Skipping...
# Processing Record 296 | George
# Processing Record 297 | Broome
# Processing Record 298 | Alofi
# Processing Record 299 | Kirakira
# Processing Record 300 | Porto Walter
# Processing Record 301 | San Lorenzo
# Processing Record 302 | Kisangani
# Processing Record 303 | Saldanha
# Processing Record 304 | Bethel
# Processing Record 305 | Ozernovskiy
# Processing Record 306 | Pontian Kecil
# Processing Record 307 | Aliaga
# Processing Record 308 | Wajima
# Processing Record 309 | Jalingo
# Processing Record 310 | Namwala
# Processing Record 311 | Basco
# Processing Record 312 | Ilulissat
# Processing Record 313 | Manta
# Processing Record 314 | Viedma
# Processing Record 315 | Iki-Burul
# Processing Record 316 | Lárdos
# Processing Record 317 | Chute-aux-Outardes
# Processing Record 318 | Sirsāganj
# Processing Record 319 | Fare
# Processing Record 320 | East Linton
# Processing Record 321 | Nguruka
# Processing Record 322 | Beringovskiy
# Processing Record 323 | Vīsāvadar
# Processing Record 324 | Alugan
# Processing Record 325 | Sibolga
# Processing Record 326 | Norrtälje
# Processing Record 327 | Mandeville
# Processing Record 328 | Ambilobe
# Processing Record 329 | Sinnamary
# Processing Record 330 | Lago da Pedra
# City not found. Skipping...
# Processing Record 331 | Dossor
# City not found. Skipping...
# Processing Record 332 | Yüksekova
# Processing Record 333 | São João da Barra
# Processing Record 334 | Tomatlán
# City not found. Skipping...
# Processing Record 335 | Kokuy
# Processing Record 336 | Grindavik
# Processing Record 337 | Drexel Heights
# City not found. Skipping...
# Processing Record 338 | Port Elizabeth
# City not found. Skipping...
# Processing Record 339 | Kunashak
# Processing Record 340 | Warrnambool
# Processing Record 341 | Veshenskaya
# Processing Record 342 | Mazyr
# Processing Record 343 | Kondinskoye
# Processing Record 344 | Ponferrada
# Processing Record 345 | Sovetskiy
# Processing Record 346 | Oodweyne
# Processing Record 347 | Riyadh
# Processing Record 348 | Vredendal
# Processing Record 349 | Kiel
# Processing Record 350 | Edd
# Processing Record 351 | Mwinilunga
# Processing Record 352 | Korsakovo
# Processing Record 353 | Menzel Salem
# Processing Record 354 | Malakal
# Processing Record 355 | San Quintín
# Processing Record 356 | Muroto-misakicho
# Processing Record 357 | Mahanoro
# Processing Record 358 | Black Diamond
# Processing Record 359 | Killybegs
# Processing Record 360 | Lüderitz
# Processing Record 361 | Honiara
# Processing Record 362 | Huarmey
# Processing Record 363 | Port Blair
# Processing Record 364 | Hasaki
# Processing Record 365 | Poconé
# Processing Record 366 | Qandala
# Processing Record 367 | Inuvik
# Processing Record 368 | Ambulu
# Processing Record 369 | Ust-Nera
# Processing Record 370 | Lakota
# Processing Record 371 | Ngawen
# Processing Record 372 | Vanimo
# Processing Record 373 | Caravelas
# Processing Record 374 | Touros
# Processing Record 375 | Reconquista
# Processing Record 376 | Maputo
# City not found. Skipping...
# Processing Record 377 | Bobrovka
# Processing Record 378 | Narsaq
# Processing Record 379 | Beian
# Processing Record 380 | Ahipara
# Processing Record 381 | Maslovare
# Processing Record 382 | St. George's
# Processing Record 383 | Port Shepstone
# Processing Record 384 | Newport
# Processing Record 385 | Bajram Curri
# Processing Record 386 | Matadi
# Processing Record 387 | Falun
# Processing Record 388 | Kulhudhuffushi
# City not found. Skipping...
# Processing Record 389 | Blagoveshchenka
# Processing Record 390 | Ambanja
# Processing Record 391 | Namatanai
# Processing Record 392 | Panguna
# Processing Record 393 | Hauterive
# Processing Record 394 | Ust'-Kut
# Processing Record 395 | Kyshtovka
# Processing Record 396 | Yarmouth
# Processing Record 397 | Middelburg
# Processing Record 398 | Mapiripán
# Processing Record 399 | La Ronge
# Processing Record 400 | Caucayá
# Processing Record 401 | Altay
# Processing Record 402 | Salinópolis
# Processing Record 403 | Vila Franca do Campo
# Processing Record 404 | Puerto Escondido
# Processing Record 405 | Key West
# Processing Record 406 | Shingū
# City not found. Skipping...
# Processing Record 407 | Eyl
# Processing Record 408 | Berlevåg
# Processing Record 409 | Makkah al Mukarramah
# Processing Record 410 | Borba
# Processing Record 411 | Damāvand
# Processing Record 412 | Imbituba
# Processing Record 413 | Dingle
# City not found. Skipping...
# Processing Record 414 | Cabreúva
# Processing Record 415 | Malbork
# Processing Record 416 | Burns Lake
# Processing Record 417 | Apiaí
# Processing Record 418 | Kolondiéba
# Processing Record 419 | Mossamedes
# Processing Record 420 | Córdoba
# Processing Record 421 | Kpandu
# Processing Record 422 | Inírida
# City not found. Skipping...
# Processing Record 423 | Synya
# Processing Record 424 | Rundu
# Processing Record 425 | Novy Urengoy
# Processing Record 426 | Phan Thiet
# Processing Record 427 | Leshukonskoye
# Processing Record 428 | Kathu
# Processing Record 429 | Dyersburg
# Processing Record 430 | Dzhebariki-Khaya
# Processing Record 431 | Kumul
# Processing Record 432 | San Isidro
# Processing Record 433 | Pemangkat
# Processing Record 434 | High Level
# Processing Record 435 | Coahuayana Viejo
# Processing Record 436 | Flinders
# Processing Record 437 | Djibouti
# Processing Record 438 | Panacan
# Processing Record 439 | Kaligutan
# Processing Record 440 | Faya
# Processing Record 441 | Coyhaique
# Processing Record 442 | Smithers
# City not found. Skipping...
# Processing Record 443 | Sorong
# City not found. Skipping...
# Processing Record 444 | Homer
# Processing Record 445 | Verkhoyansk
# Processing Record 446 | Lázaro Cárdenas
# Processing Record 447 | Soe
# Processing Record 448 | Vila Velha
# Processing Record 449 | Vostok
# Processing Record 450 | Mapastepec
# Processing Record 451 | Yarovoy
# Processing Record 452 | Platteville
# Processing Record 453 | Bandarbeyla
# Processing Record 454 | Ugoofaaru
# Processing Record 455 | Behbahān
# Processing Record 456 | Lokosovo
# Processing Record 457 | Anloga
# Processing Record 458 | Prince George
# Processing Record 459 | Merritt
# Processing Record 460 | Quatre Cocos
# Processing Record 461 | Takoradze
# Processing Record 462 | Yerbogachën
# Processing Record 463 | Nouadhibou
# Processing Record 464 | Walvis Bay
# Processing Record 465 | Samarai
# Processing Record 466 | Tautira
# City not found. Skipping...
# Processing Record 467 | Trujillo
# Processing Record 468 | Puerto Parra
# Processing Record 469 | Changji
# Processing Record 470 | Oranjemund
# Processing Record 471 | Gaoyou
# Processing Record 472 | Najrān
# Processing Record 473 | Çeşme
# Processing Record 474 | Wattegama
# Processing Record 475 | Green Valley
# Processing Record 476 | Clarence Town
# Processing Record 477 | Mucurapo
# Processing Record 478 | North Battleford
# Processing Record 479 | Chipata
# Processing Record 480 | Nuuk
# Processing Record 481 | Mil'kovo
# Processing Record 482 | Novorudnyy
# Processing Record 483 | Fortuna
# Processing Record 484 | Sokoto
# City not found. Skipping...
# Processing Record 485 | Hongjiang
# Processing Record 486 | Laas
# Processing Record 487 | Mazagão
# Processing Record 488 | Puerto Madryn
# Processing Record 489 | Songea
# Processing Record 490 | Sabha
# Processing Record 491 | Buraidah
# Processing Record 492 | Carnot
# Processing Record 493 | Upata
# Processing Record 494 | Chimbote
# Processing Record 495 | Rāmgarh
# Processing Record 496 | Saint-Augustin
# Processing Record 497 | Olinda
# Processing Record 498 | Teknāf
# Processing Record 499 | Coffs Harbour
# Processing Record 500 | Redwater
# Processing Record 501 | Hailar
# Processing Record 502 | Osypenko
# Processing Record 503 | Gisborne
# Processing Record 504 | Tilichiki
# Processing Record 505 | Ananas
# Processing Record 506 | Jega
# Processing Record 507 | Provincie Utrecht
# Processing Record 508 | Khāsh
# Processing Record 509 | Bonthe
# Processing Record 510 | Atar
# Processing Record 511 | Marsaxlokk
# Processing Record 512 | Lakatoro
# Processing Record 513 | Kasempa
# Processing Record 514 | Polson
# Processing Record 515 | Santa Isabel Rio Negro
# City not found. Skipping...
# Processing Record 516 | Christchurch
# Processing Record 517 | Lashio
# Processing Record 518 | Buala
# City not found. Skipping...
# Processing Record 519 | Coxim
# Processing Record 520 | Payerne
# Processing Record 521 | Wildwood
# Processing Record 522 | Santa Marta
# Processing Record 523 | Palu
# Processing Record 524 | Lékoni
# Processing Record 525 | Muros
# Processing Record 526 | Guadalupe Victoria
# Processing Record 527 | Kichera
# Processing Record 528 | Lodja
# Processing Record 529 | Acapulco de Juárez
# Processing Record 530 | Ardakān
# Processing Record 531 | Belyy Yar
# Processing Record 532 | Grand-Lahou
# Processing Record 533 | Baruun-Urt
# Processing Record 534 | Matamoros
# Processing Record 535 | Ixtapa
# Processing Record 536 | Kota Belud
# Processing Record 537 | Bubaque
# Processing Record 538 | Konakovo
# Processing Record 539 | Ponta Delgada
# Processing Record 540 | Taoudenni
# Processing Record 541 | Masuda
# Processing Record 542 | Tual
# Processing Record 543 | Roald
# Processing Record 544 | Diego de Almagro
# Processing Record 545 | Tutayev
# Processing Record 546 | Teahupoo
# Processing Record 547 | Rāvar
# Processing Record 548 | Dūngarpur
# Processing Record 549 | Poya
# Processing Record 550 | Quelimane
# Processing Record 551 | Sabanagrande
# Processing Record 552 | Brae
# Processing Record 553 | Kharp
# Processing Record 554 | Rocafuerte
# Processing Record 555 | Svetlaya
# Processing Record 556 | Novoagansk
# City not found. Skipping...
# Processing Record 557 | Włoszczowa
# Processing Record 558 | Atasū
# Processing Record 559 | Rawson
# Processing Record 560 | Deniliquin
# Processing Record 561 | Gerāsh
# Processing Record 562 | Plyussa
# Processing Record 563 | Mardin
# Processing Record 564 | Natal
# Processing Record 565 | Lompoc
# Processing Record 566 | Prokhorovka
# Processing Record 567 | Pascagoula
# Processing Record 568 | Malanje
# Processing Record 569 | Eureka
# City not found. Skipping...
# Processing Record 570 | Obo
# Processing Record 571 | Maceió
# Processing Record 572 | Pisco
# Processing Record 573 | Sitka
# Processing Record 574 | Diamantino
# Processing Record 575 | Ürümqi
# Processing Record 576 | Hirtshals
# Processing Record 577 | Bac Lieu
# Processing Record 578 | Herat Province
# Processing Record 579 | Beyneu
# Processing Record 580 | Cap Malheureux
# Processing Record 581 | Calamar
# City not found. Skipping...
# Processing Record 582 | Kibakwe
# Processing Record 583 | Puerto Maldonado
# Processing Record 584 | Hamilton
# Processing Record 585 | Conde
# Processing Record 586 | Guerrero Negro
# Processing Record 587 | Chupaca
# Processing Record 588 | Porto Santo
# Processing Record 589 | Bethanien
# Processing Record 590 | Goundam
# Processing Record 591 | Tando Jam
# Processing Record 592 | Santiago del Estero
# Processing Record 593 | Ust-Kuyga
# Processing Record 594 | Tricase
# Processing Record 595 | Altagracia de Orituco
# Processing Record 596 | Onega
# Processing Record 597 | Berbera
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a DataFrame from Cities, Latitude, Longitude, Temperature, Humidity, Cloudiness & Wind Speed
weather_dict = {
    "City": city_name,
    "Country": country,
    "Date": date,
    "Latitude": latitude,
    "Longitude": longitude,
    "Max Temperature": max_temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               597
# Country            597
# Date               597
# Latitude           597
# Longitude          597
# Max Temperature    597
# Humidity           597
# Cloudiness         597
# Wind Speed         597
# dtype: int64

# %%
# Display DataFrame
weather_data.head()
# Out:
#            City Country        Date  Latitude  Longitude  Max Temperature  \
# 0       Mataura      NZ  1604730433    -46.19     168.86            44.11
# 1      Cidreira      BR  1604730433    -30.18     -50.21            66.72
# 2         Ancud      CL  1604730433    -41.87     -73.82            46.00
# 3      Bengkulu      ID  1604730434     -3.80     102.27            83.79
# 4  Norman Wells      CA  1604730202     65.28    -126.83            10.40
#
#    Humidity  Cloudiness  Wind Speed
# 0        96         100        3.89
# 1        85           1       15.32
# 2        80          98        5.82
# 3        75          25        8.10
# 4        92          90        2.24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Max Temperature"], facecolors="red", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Max Temperature (02/01/2019)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Max_Temperature.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Humidity"], facecolors="green", marker="o", edgecolor="black")
# Incorporate Other Graph Properties
plt.title("City Latitude vs. Humidity (02/01/2019)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Humidity.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Cloudiness (02/01/2019)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Cloudiness.png")

# Show Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Latitude"], weather_data["Wind Speed"], facecolors="yellow", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("City Latitude vs. Wind Speed (02/01/2019)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City_Latitude_vs_Wind_Speed.png")

# Show Plot
plt.show()
